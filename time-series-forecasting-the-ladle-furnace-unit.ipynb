# %% [markdown]
# <a href="https://www.kaggle.com/code/aleksandrmorozov123/time-series-forecasting-the-ladle-furnace-unit?scriptVersionId=115758827" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_wire.csv
# /kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_wire_time.csv
# /kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_bulk.csv
# /kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_temp.csv
# /kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_bulk_time.csv
# /kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_gas.csv
# /kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_arc.csv
# /kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_temp_FULL_with_test.csv

# %% [markdown]
# # **First step - exploratory data analisys**

# %% [markdown]
# **Import required libraries**

# %%
import pandas as pd
import numpy as np
import datetime as dt
import os
import warnings
from collections import UserDict
from glob import glob
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from IPython.display import Image
# %matplotlib inline
import matplotlib.dates as mpl_dates
import seaborn as sns
from statsmodels.tsa.ar_model import AutoReg, ar_select_order
from statsmodels.tsa.api import acf, pacf, graphics
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.preprocessing import MinMaxScaler
import math
from keras.models import Model, Sequential
from keras.layers import GRU, Dense
from keras.callbacks import EarlyStopping

# %% [markdown]
# **General information
# Ladle furnace unit (LFU) - metallurgical equipment for out-of-furnace steel processing in the converter shop. The LFU is a large metal ladle with a volume of about 100 tons and is lined from the inside with refractory bricks. Molten steel is poured into the LFU from a steel ladle and then heated by graphite electrodes inserted into the unit's lid.
#
# In addition to electric heating, desulfurization (removal of sulfur from the melt), adjustment of the chemical composition, and sampling are carried out at the CPC. Alloying of metal is carried out both with lumpy ferroalloys through the system to supply bulk materials from bunkers and with wire materials through a tube apparatus. Averaging the chemical composition and temperature is carried out through the bottom purge device in the steel ladle.
#
# After completion of processing at the LFU, the melt is poured back into the steel ladle and either sent to other metal finishing units or to a continuous casting plant, where it solidifies in the form of metallurgical slabs.
#
# Content
# Each time the melt enters the Ladle Furnace Unit, the initial temperature and chemical composition are measured. Then, if necessary, the melt is heated for several minutes, after which alloying materials are added, purged with a gas, stirring the melt, and measurements are again carried out following the approved Technological Instruction. This cycle is repeated several times until the target chemistry and melting temperature are reached. In this case, it is not necessary that the melt would be heated in each cycle.
#
# The given datasets provide information on the main technological operations performed at the Ladle Furnace Unit (such as heating, ferroalloy output, chemistry measurement, etc.) with a time reference.
#
# Files
# data_gas.csv - the file with supplied gases for purging
# data_bulk.csv - the file with the given bulk elements
# data_bulk_time.csv - the file with the time of bulk delivery
# data_wire.csv - the file with wire supply
# data_wire_time.csv - the file with wire recoil time
# data_arc.csv - the file with information on the supplied electricity
# data_temp.csv - the file with temperature measurements
# The latter file is missing part of the temperature measurements.
#
# data_temp_FULL_with_test.csv with the test sample
# There is no information about the decoding of the wire and bulk parameters.
#
# The main problem
# Temperature forecasting: it is required to build a model that will predict what temperature measurements were at these points in time. First, let's try to build a simple model based on historical data only for temperature.**

# %% [markdown]
# **Read the datasets**

# %%
temp = pd.read_csv ('/kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_temp.csv')
temp.head (10)
# Out:
#    key                 time  Temperature
# 0    1  2019-05-03 11:16:18       1571.0
# 1    1  2019-05-03 11:25:53       1604.0
# 2    1  2019-05-03 11:29:11       1618.0
# 3    1  2019-05-03 11:30:01       1601.0
# 4    1  2019-05-03 11:30:39       1613.0
# 5    2  2019-05-03 11:37:27       1581.0
# 6    2  2019-05-03 11:38:00       1577.0
# 7    2  2019-05-03 11:49:38       1589.0
# 8    2  2019-05-03 11:55:50       1604.0
# 9    2  2019-05-03 11:58:24       1608.0

# %%
temp_test = pd.read_csv ('/kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_temp_FULL_with_test.csv')
temp_test.head (10)
# Out:
#    key                 time  Temperature
# 0    1  2019-05-03 11:16:18       1571.0
# 1    1  2019-05-03 11:25:53       1604.0
# 2    1  2019-05-03 11:29:11       1618.0
# 3    1  2019-05-03 11:30:01       1601.0
# 4    1  2019-05-03 11:30:39       1613.0
# 5    2  2019-05-03 11:37:27       1581.0
# 6    2  2019-05-03 11:38:00       1577.0
# 7    2  2019-05-03 11:49:38       1589.0
# 8    2  2019-05-03 11:55:50       1604.0
# 9    2  2019-05-03 11:58:24       1608.0

# %% [markdown]
# **Check the rows with empty values**

# %%
temp.isna ().sum ()
# Out:
# key               0
# time              0
# Temperature    2901
# dtype: int64

# %%
temp_test.isna ().sum ()
# Out:
# key            0
# time           0
# Temperature    0
# dtype: int64

# %%
# drop the missing values
temp = temp.dropna ()
temp.count ()
# Out:
# key            13006
# time           13006
# Temperature    13006
# dtype: int64

# %% [markdown]
# **We transform the data into a date series format, since only in this way it will be possible to process the data**

# %%
# convert datasets to time series
temp ['time'] = pd.to_datetime(temp['time']) 
temp_test ['time'] = pd.to_datetime(temp_test ['time'])

# %%
temp.describe()
# Out:
#                 key   Temperature
# count  13006.000000  13006.000000
# mean    1328.447793   1591.840920
# std      804.740001     21.375851
# min        1.000000   1191.000000
# 25%      638.000000   1581.000000
# 50%     1315.000000   1591.000000
# 75%     1977.750000   1601.000000
# max     3241.000000   1705.000000

# %%
temp_test.describe()
# Out:
#                 key   Temperature
# count  15907.000000  15907.000000
# mean    1607.880870   1592.149431
# std      942.212073     21.058244
# min        1.000000   1189.000000
# 25%      790.000000   1581.000000
# 50%     1618.000000   1591.000000
# 75%     2427.000000   1601.000000
# max     3241.000000   1705.000000

# %% [markdown]
# **Create a lag plot for datasets. Lag plots are used to check if a time series is random: random data should not exhibit any structure in the lag plot**

# %%
pd.options.display.float_format = "{:, .2f}".format
np.set_printoptions (precision = 2)
warnings.filterwarnings ("ignore")

# import lag_plot function
from pandas.plotting import lag_plot
sns.set ()

# pass the lag argument and plot the values
# when lag = 1 the plot is essentially data [:-1] vs. data [1:]
# plot our temperature data set
lag_plot (temp ['time'])
# Out:
# <AxesSubplot:xlabel='y(t)', ylabel='y(t + 1)'>

# %% [markdown]
# *As we can see, the data has a clear linear structure.*

# %% [markdown]
# **Create an autocorrelation plot for datasets. Autocorrelation plots applied to check randomness in time series by computing autocorrelations for data values at fluctuating time lags. It is heavily used in time series analysis and forecasting. We can calculate the correlation for current time-series observations with observations of previous time steps called lags.**

# %%
# import autocorrelation plot function
from pandas.plotting import autocorrelation_plot
sns.set ()

# pass the autocorrelation argument and plot the values temperature
temp.reset_index(inplace=True)
temp ['time'] = temp ['time'].apply(mpl_dates.date2num)
temp ['time'] = temp ['time'].astype(float)
autocorrelation_plot (temp ['time'])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
# import plot_acf () function
from statsmodels.graphics.tsaplots import plot_acf

# plot the acf function on the temperature data set
plot_acf (temp ['time'])
plt.show ()

# %%
# import plor_pacf () function
from statsmodels.graphics.tsaplots import plot_pacf

# plot the pacf fucntion on the holiday dataset
plot_pacf (temp ['time'], lags = 20)
plt.show ()

# %% [markdown]
# **Autoregression modeling.
# Autoregression is a time series model that uses observations from previous time steps as input to a regression equation to predict the value at the next time step. It is a very simple idea that can result in accurate forecasts on a range of time series problems.**

# %%
# apply AutoReg model for temperature dataset
modelT = AutoReg (temp ['time'], 1)
resultsT = modelT.fit ()
resultsT.summary ()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:                   time   No. Observations:                13006
# Model:                     AutoReg(1)   Log Likelihood               21742.953
# Method:               Conditional MLE   S.D. of innovations              0.045
# Date:                Sat, 07 Jan 2023   AIC                         -43479.906
# Time:                        18:44:54   BIC                         -43457.486
# Sample:                             1   HQIC                        -43472.415
#                                 13006
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -1.9598      0.236     -8.301      0.000      -2.423      -1.497
# time.L1        1.0001   1.31e-05   7.65e+04      0.000       1.000       1.000
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.9999           +0.0000j            0.9999            0.0000
# -----------------------------------------------------------------------------
# """

# %% [markdown]
# **Visualize the forecasts**

# %%
# define figure style, plot package and default figure size
sns.set_style ('darkgrid')
pd.plotting.register_matplotlib_converters ()

# default figure size
sns.mpl.rc ('figure', figsize = (18, 8))

# use plot_predict and visualize forecasts for temperature dataset
figure = resultsT.plot_predict (120, 490)

# %% [markdown]
# **Plot_diagnostics indicates that the model captures the key features in the data. They help us determine visually how our model is fitting the data and if any of the basic assumptions of an OLS (ordinary least squares) model are being violated.**

# %%
# define default figure size
fig = plt.figure (figsize = (18, 10))

# use plot_predict and visualize forecasts for temperature dataset
fig = resultsT.plot_diagnostics (fig = fig, lags = 30)

# %% [markdown]
# **Training the model for temperature dataset**

# %%
from sklearn.model_selection import train_test_split
# create train set containing only the model features
X = temp
y = temp_test [1:13007]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

print ('Training data shape X: ', X_train.shape)
print ('Test data shape y: ', y_test.shape)
# Out:
# Training data shape X:  (8714, 4)
# Test data shape y:  (4292, 3)

# %%
# scale train data to be in range (0, 1)
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler ()
X_train = scaler.fit_transform (X_train)

# scale test data to be in range (0, 1)
X_test = scaler.transform (X_test)

# specify the number of steps to forecast ahead
HORIZON = 3
print ('Forecasting horizon: ', HORIZON, 'days')
# Out:
# Forecasting horizon:  3 days

# %%
# make predictions on the test data
training_window = 720

history = [x for x in X_train]
history = history [(-training_window):]
predictions = list ()

for t in range (X_test.shape [0]):
    modelT = AutoReg (temp ['time'], 1)
    modelT_fit = modelT.fit ()
    yhat = modelT_fit.predict
    predictions.append (yhat)
    obs = list (X_test [t])
    # move the trainig window
    history.append (obs [0])
    history.pop (0)
    print (X_test [t])
    print (t+1, ': predicted =', yhat, 'expected =', obs)
# Out:
# [0.51 0.51 0.49 0.77]
# 1 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446bf06210>> expected = [0.5091503679013898, 0.5089506172839506, 0.48803948884224724, 0.7680311890838207]
# [0.73 0.73 0.74 0.73]
# 2 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462520b10>> expected = [0.7298283126847368, 0.7283950617283951, 0.7424793032739103, 0.7309941520467835]
# [0.62 0.61 0.64 0.75]
# 3 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462520ed0>> expected = [0.617193887176907, 0.6135802469135803, 0.6370155440374958, 0.7485380116959064]
# [0.25 0.24 0.24 0.83]
# 4 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446bef89d0>> expected = [0.2479718256713414, 0.24135802469135803, 0.24019364669078413, 0.8343079922027292]
# [0.72 0.72 0.73 0.78]
# 5 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446bef81d0>> expected = [0.7203949437142317, 0.719753086419753, 0.734312908203492, 0.7797270955165692]
# [0.58 0.58 0.56 0.84]
# 6 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462528210>> expected = [0.5834224262624992, 0.582716049382716, 0.5564468327480938, 0.8362573099415207]
# [0.83 0.83 0.84 0.74]
# 7 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462528c90>> expected = [0.8347273756367524, 0.8333333333333333, 0.8433083614399379, 0.7407407407407409]
# [0.65 0.65 0.67 0.75]
# 8 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446bef8e10>> expected = [0.6512169045971952, 0.6472222222222221, 0.6688263945315214, 0.7465886939571149]
# [0.4  0.4  0.39 0.77]
# 9 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462528d50>> expected = [0.40236463115527327, 0.399074074074074, 0.3860249522025754, 0.7719298245614037]
# [0.79 0.78 0.8  0.74]
# 10 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462531590>> expected = [0.7854851896107162, 0.7848765432098765, 0.7971191012688621, 0.7446393762183234]
# [0.03 0.02 0.02 0.76]
# 11 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44625317d0>> expected = [0.029369222061505565, 0.024382716049382715, 0.02289012977450966, 0.7641325536062378]
# [0.16 0.15 0.15 0.8 ]
# 12 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462531a90>> expected = [0.1591094899691843, 0.14814814814814814, 0.14787467837351187, 0.7992202729044835]
# [0.6  0.59 0.61 0.76]
# 13 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44625314d0>> expected = [0.5960002515565058, 0.5938271604938271, 0.6113968574751425, 0.7621832358674463]
# [0.22 0.22 0.21 0.85]
# 14 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446253c150>> expected = [0.22206150556568766, 0.21512345679012346, 0.21309977687650417, 0.8499025341130606]
# [0.36 0.36 0.35 0.78]
# 15 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446253c810>> expected = [0.35909691214389033, 0.3567901234567901, 0.3479785923416614, 0.7797270955165692]
# [0.13 0.12 0.12 0.77]
# 16 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446253cbd0>> expected = [0.13376517200176088, 0.12314814814814815, 0.12303611374801449, 0.7699805068226122]
# [0.29 0.29 0.28 0.82]
# 17 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462531a50>> expected = [0.29293755109741526, 0.2861111111111111, 0.2837067098254238, 0.8187134502923978]
# [0.86 0.85 0.87 0.77]
# 18 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446253c390>> expected = [0.8560467895100936, 0.8546296296296296, 0.8661877507526299, 0.7680311890838207]
# [0.43 0.43 0.41 0.73]
# 19 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462542290>> expected = [0.4313565184579586, 0.42808641975308637, 0.4143790042383557, 0.729044834307992]
# [0.22 0.21 0.2  0.73]
# 20 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44625429d0>> expected = [0.21508081252751396, 0.20709876543209876, 0.20474187553588763, 0.732943469785575]
# [0.28 0.27 0.27 0.8 ]
# 21 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462542b90>> expected = [0.277341047732847, 0.2703703703703703, 0.2687137922969498, 0.801169590643275]
# [0.52 0.52 0.5  0.73]
# 22 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462542e10>> expected = [0.5219168605748066, 0.5206790123456789, 0.4983580039503863, 0.7270955165692006]
# [0.22 0.21 0.21 0.72]
# 23 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44625426d0>> expected = [0.21866549273630587, 0.21141975308641975, 0.20899087895051593, 0.7153996101364521]
# [0.17 0.16 0.16 0.78]
# 24 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446244c790>> expected = [0.16803974592792903, 0.1574074074074074, 0.15723393598511848, 0.7797270955165692]
# [4.40e-04 3.09e-04 1.72e-04 8.05e-01]
# 25 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446244cb50>> expected = [0.00044022388529023327, 0.00030864197530864197, 0.00017232687406476543, 0.8050682261208579]
# [0.54 0.54 0.52 0.84]
# 26 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446244c4d0>> expected = [0.5447456134834286, 0.5447530864197531, 0.5199042334393482, 0.8440545808966862]
# [0.52 0.52 0.5  0.78]
# 27 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446244ccd0>> expected = [0.5186466259983649, 0.5182098765432098, 0.49583543387680606, 0.7777777777777777]
# [0.75 0.74 0.76 0.77]
# 28 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462455410>> expected = [0.745236148669895, 0.7435185185185185, 0.7591701727402267, 0.7738791423001952]
# [0.22 0.21 0.2  0.8 ]
# 29 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624559d0>> expected = [0.21526947990692408, 0.20709876543209876, 0.20489377635311712, 0.797270955165692]
# [0.21 0.2  0.2  0.81]
# 30 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462455ad0>> expected = [0.21218791270989243, 0.20401234567901236, 0.20169877665182412, 0.8050682261208579]
# [0.65 0.65 0.67 0.74]
# 31 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462455990>> expected = [0.651154015470725, 0.6472222222222221, 0.6687958033947154, 0.7426900584795324]
# [0.22 0.21 0.21 0.81]
# 32 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446244ce50>> expected = [0.21633859505691463, 0.20864197530864198, 0.20605259546618981, 0.8089668615984404]
# [0.37 0.37 0.36 0.78]
# 33 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446245c950>> expected = [0.3691591723790956, 0.3675925925925926, 0.35683813078756543, 0.7777777777777777]
# [0.27 0.26 0.26 0.8 ]
# 34 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446245cd90>> expected = [0.26765612225646185, 0.26111111111111107, 0.259390591950023, 0.797270955165692]
# [0.65 0.65 0.67 0.69]
# 35 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446245ce10>> expected = [0.6542984717942267, 0.6499999999999999, 0.6718668083001376, 0.6900584795321638]
# [0.03 0.03 0.03 0.83]
# 36 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462477250>> expected = [0.032073454499717, 0.027469135802469135, 0.025401000416508168, 0.8323586744639377]
# [0.67 0.66 0.68 0.77]
# 37 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462455710>> expected = [0.6666876297088233, 0.662037037037037, 0.6836086263937204, 0.7660818713450293]
# [0.49 0.49 0.47 0.77]
# 38 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462477dd0>> expected = [0.49009496258096974, 0.48796296296296293, 0.47122855635632277, 0.7699805068226122]
# [0.37 0.37 0.36 0.77]
# 39 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462477cd0>> expected = [0.37412741337022826, 0.3722222222222222, 0.3611070807741328, 0.7738791423001952]
# [0.02 0.02 0.02 0.81]
# 40 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446245c410>> expected = [0.022136972517451732, 0.017901234567901235, 0.01690596639369346, 0.807017543859649]
# [0.69 0.69 0.71 0.81]
# 41 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446247f690>> expected = [0.6907112760203761, 0.6876543209876543, 0.7053391698793234, 0.8128654970760234]
# [0.37 0.36 0.35 0.76]
# 42 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446247fdd0>> expected = [0.3652600465379536, 0.3638888888888889, 0.3536272121875186, 0.7563352826510723]
# [0.59 0.59 0.61 0.79]
# 43 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446247fe50>> expected = [0.5949940255329853, 0.5925925925925926, 0.6099677047738794, 0.7914230019493176]
# [0.57 0.57 0.55 0.85]
# 44 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624c7310>> expected = [0.5748066159361046, 0.5743827160493827, 0.5466926713705504, 0.8499025341130606]
# [0.27 0.26 0.26 0.84]
# 45 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446247f210>> expected = [0.2690396830388026, 0.2623456790123456, 0.2613828517211232, 0.8382066276803117]
# [0.85 0.85 0.86 0.74]
# 46 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624c7dd0>> expected = [0.8531538896924721, 0.8518518518518519, 0.8622809077646707, 0.7446393762183234]
# [0.49 0.49 0.48 0.76]
# 47 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624c7550>> expected = [0.49430853405446196, 0.4929012345679012, 0.4752026231276716, 0.7563352826510723]
# [0.52 0.52 0.5  0.78]
# 48 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624ce310>> expected = [0.5240550908747877, 0.5219135802469136, 0.49947980682898674, 0.7836257309941521]
# [0.99 0.98 0.99 0.81]
# 49 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624ce850>> expected = [0.9861643921765926, 0.9839506172839506, 0.9862097265046827, 0.8109161793372319]
# [0.97 0.97 0.97 0.74]
# 50 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624cef10>> expected = [0.9711338909502546, 0.9688271604938271, 0.9720220559219399, 0.7446393762183234]
# [0.53 0.53 0.5  0.78]
# 51 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624cef50>> expected = [0.52820577322181, 0.5262345679012346, 0.5026321323739182, 0.7758284600389862]
# [0.22 0.21 0.21 0.76]
# 52 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624d8490>> expected = [0.21973460788629642, 0.2123456790123457, 0.21032825824136125, 0.7641325536062378]
# [0.75 0.75 0.77 0.69]
# 53 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624d8a90>> expected = [0.7548581850198101, 0.7537037037037037, 0.7674583569759648, 0.6861598440545809]
# [0.39 0.38 0.37 0.8 ]
# 54 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624ce790>> expected = [0.3862650147789447, 0.38271604938271603, 0.3710009640523424, 0.801169590643275]
# [0.68 0.68 0.69 0.72]
# 55 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624d8ed0>> expected = [0.6797685680145903, 0.6756172839506173, 0.6943544584472363, 0.7173489278752436]
# [0.66 0.65 0.67 0.88]
# 56 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624df150>> expected = [0.6559335890824476, 0.6509259259259259, 0.6732929881949872, 0.8849902534113059]
# [0.2  0.19 0.19 0.75]
# 57 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624dfb10>> expected = [0.20181120684233694, 0.19382716049382717, 0.19032990191561794, 0.7524366471734893]
# [0.02 0.02 0.02 0.79]
# 58 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624dff50>> expected = [0.023772089805672598, 0.019444444444444445, 0.018647455560625303, 0.7914230019493176]
# [0.05 0.04 0.04 0.8 ]
# 59 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624d8150>> expected = [0.04672662096723476, 0.03950617283950617, 0.03923605780170192, 0.7992202729044835]
# [0.1  0.09 0.09 0.76]
# 60 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624e8450>> expected = [0.09816992641972201, 0.08641975308641976, 0.08744663452904433, 0.7602339181286548]
# [0.53 0.52 0.5  0.77]
# 61 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624e8b10>> expected = [0.5261933211747689, 0.5237654320987654, 0.5006916569722648, 0.7660818713450293]
# [0.43 0.43 0.42 0.79]
# 62 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624e8cd0>> expected = [0.4322369662285391, 0.429320987654321, 0.41533327509191054, 0.7855750487329436]
# [0.71 0.71 0.72 0.76]
# 63 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624e8c90>> expected = [0.7104584617319665, 0.7089506172839506, 0.7247386495614592, 0.7621832358674463]
# [0.71 0.71 0.72 0.81]
# 64 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624ef810>> expected = [0.7078171184202251, 0.7064814814814815, 0.7226676583693177, 0.8128654970760234]
# [0.58 0.58 0.55 0.78]
# 65 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624d8f10>> expected = [0.5797119678007672, 0.5793209876543209, 0.5519001651058204, 0.7797270955165692]
# [0.54 0.54 0.51 0.8 ]
# 66 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624eff90>> expected = [0.5391484812275957, 0.5401234567901234, 0.5133156313900713, 0.801169590643275]
# [0.55 0.55 0.52 0.8 ]
# 67 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624ef910>> expected = [0.5486447393245708, 0.549074074074074, 0.5230208853075169, 0.7953216374269005]
# [0.54 0.54 0.52 0.77]
# 68 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624d8dd0>> expected = [0.5431733853216778, 0.5432098765432098, 0.5186927668839587, 0.7719298245614037]
# [0.27 0.27 0.26 0.82]
# 69 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624f7850>> expected = [0.27193258285642413, 0.26543209876543206, 0.26473541016147806, 0.8167641325536064]
# [0.15 0.14 0.14 0.75]
# 70 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624f7f90>> expected = [0.15414124897805168, 0.14290123456790124, 0.14192043485061845, 0.7543859649122808]
# [0.26 0.26 0.26 0.77]
# 71 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624f7c50>> expected = [0.26369410728884973, 0.25771604938271603, 0.2558230324792419, 0.7719298245614037]
# [0.07 0.06 0.06 0.79]
# 72 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462500850>> expected = [0.06999559776114708, 0.060802469135802464, 0.05987663620626904, 0.7875243664717351]
# [0.22 0.21 0.21 0.79]
# 73 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462500c90>> expected = [0.22130683604804727, 0.21388888888888888, 0.211980467319421, 0.7914230019493176]
# [0.02 0.02 0.02 0.91]
# 74 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44625004d0>> expected = [0.019055405320420098, 0.016049382716049384, 0.01513618761748603, 0.9103313840155947]
# [0.34 0.34 0.33 0.72]
# 75 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462500e10>> expected = [0.3437519652852022, 0.3391975308641975, 0.33211790303607813, 0.7231968810916181]
# [0.62 0.62 0.64 0.79]
# 76 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462485810>> expected = [0.6234827998239104, 0.6194444444444444, 0.6438787950390861, 0.7933723196881091]
# [0.32 0.31 0.31 0.72]
# 77 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462485c50>> expected = [0.31953965159423936, 0.31481481481481477, 0.3096090596562817, 0.7173489278752436]
# [0.48 0.48 0.47 0.85]
# 78 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462485090>> expected = [0.48462360857807685, 0.48209876543209873, 0.46569088931696, 0.8518518518518516]
# [0.62 0.62 0.64 0.83]
# 79 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446248f150>> expected = [0.6246776932268411, 0.6203703703703703, 0.644961088361697, 0.8284600389863548]
# [0.2  0.2  0.19 0.78]
# 80 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462500e90>> expected = [0.20394943714231806, 0.1962962962962963, 0.19329676270012897, 0.7758284600389862]
# [0.12 0.11 0.11 0.82]
# 81 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446248f690>> expected = [0.12257090749009494, 0.11111111111111112, 0.11291351617114742, 0.8245614035087718]
# [0.26 0.25 0.25 0.7 ]
# 82 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446248fdd0>> expected = [0.2567763033771461, 0.2506172839506173, 0.24901262071392694, 0.6959064327485378]
# [0.04 0.03 0.03 0.85]
# 83 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446248f6d0>> expected = [0.04062637569964153, 0.0345679012345679, 0.03216240882474608, 0.8460038986354776]
# [0.49 0.49 0.48 0.73]
# 84 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462497810>> expected = [0.4947487579397522, 0.49351851851851847, 0.47564490000200976, 0.732943469785575]
# [0.23 0.23 0.22 0.75]
# 85 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462497c90>> expected = [0.2330671026979435, 0.22685185185185186, 0.22435127370849273, 0.7504873294346979]
# [0.09 0.08 0.08 0.78]
# 86 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462497290>> expected = [0.09005722910508772, 0.07777777777777778, 0.07689633641888349, 0.7816764132553606]
# [0.34 0.34 0.33 0.8 ]
# 87 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446249f190>> expected = [0.34111062197346076, 0.33641975308641975, 0.32968739406382497, 0.7953216374269005]
# [0.07 0.06 0.06 0.74]
# 88 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624973d0>> expected = [0.06527891327589459, 0.056172839506172835, 0.05570166526067055, 0.7426900584795324]
# [0.28 0.27 0.27 0.8 ]
# 89 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446249fc90>> expected = [0.27922772152694797, 0.27191358024691353, 0.26999430467833463, 0.7992202729044835]
# [0.45 0.45 0.44 0.77]
# 90 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446249fe50>> expected = [0.45273882145776995, 0.4515432098765432, 0.4374617910468146, 0.7680311890838207]
# [0.58 0.58 0.55 0.84]
# 91 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624a7190>> expected = [0.5804666373184076, 0.5799382716049383, 0.5535208240772818, 0.8382066276803117]
# [0.65 0.64 0.66 0.78]
# 92 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624a7990>> expected = [0.6470033331237028, 0.6429012345679012, 0.6642185446156645, 0.7836257309941521]
# [0.74 0.73 0.75 0.75]
# 93 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624a7dd0>> expected = [0.7354254449405697, 0.7342592592592592, 0.7508086273143135, 0.7543859649122808]
# [0.07 0.06 0.06 0.77]
# 94 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624a7e50>> expected = [0.07175649330230802, 0.062345679012345674, 0.061226194413677604, 0.7699805068226122]
# [0.31 0.3  0.3  0.77]
# 95 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624b0450>> expected = [0.30557826551789197, 0.2993827160493827, 0.29531657367377306, 0.7660818713450293]
# [0.61 0.61 0.63 0.79]
# 96 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624b0690>> expected = [0.6120998679328343, 0.6089506172839506, 0.6315184414209227, 0.7933723196881091]
# [0.7  0.7  0.72 0.77]
# 97 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624b0d10>> expected = [0.7042324382114332, 0.7024691358024691, 0.7183436635159239, 0.7738791423001952]
# [0.08 0.07 0.07 0.8 ]
# 98 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624b0e90>> expected = [0.08332809257279415, 0.07222222222222223, 0.07194162712434604, 0.801169590643275]
# [0.76 0.76 0.77 0.74]
# 99 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624b7210>> expected = [0.7576253065844915, 0.7570987654320988, 0.7709856397148656, 0.7426900584795324]
# [0.85 0.85 0.86 0.81]
# 100 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624b79d0>> expected = [0.8542230048424627, 0.8527777777777777, 0.8633122797905912, 0.8050682261208579]
# [0.26 0.25 0.25 0.79]
# 101 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624b7e10>> expected = [0.2587258662977171, 0.2518518518518518, 0.25082363519177875, 0.7855750487329436]
# [0.06 0.05 0.05 0.8 ]
# 102 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624b7690>> expected = [0.05842399849066096, 0.05092592592592592, 0.05063120831059109, 0.801169590643275]
# [0.74 0.74 0.76 0.78]
# 103 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624bf390>> expected = [0.7427834727375636, 0.7416666666666666, 0.7573607885110221, 0.7777777777777777]
# [0.72 0.72 0.74 0.79]
# 104 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624bf9d0>> expected = [0.7231620652789132, 0.7225308641975309, 0.7367573222379633, 0.7914230019493176]
# [0.53 0.53 0.5  0.76]
# 105 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624bfe10>> expected = [0.530092447015911, 0.528395061728395, 0.5042202822689319, 0.7602339181286548]
# [0.36 0.36 0.35 0.72]
# 106 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624bfe90>> expected = [0.36349915099679264, 0.36234567901234566, 0.352320136342513, 0.7192982456140351]
# [0.48 0.48 0.46 0.79]
# 107 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462406350>> expected = [0.4787120306898937, 0.4759259259259259, 0.4605883068784067, 0.7855750487329436]
# [0.85 0.84 0.85 0.76]
# 108 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624bf350>> expected = [0.8457329727690082, 0.8435185185185184, 0.8525892712184202, 0.7641325536062378]
# [0.28 0.28 0.27 0.78]
# 109 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462406e50>> expected = [0.28306395824162, 0.2765432098765432, 0.27314020512557136, 0.7836257309941521]
# [0.08 0.07 0.07 0.74]
# 110 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462406d50>> expected = [0.08458587510219481, 0.07314814814814816, 0.0724933224535107, 0.7426900584795324]
# [0.57 0.57 0.55 0.79]
# 111 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624bf150>> expected = [0.5736746116596441, 0.5725308641975309, 0.5455808417779338, 0.7914230019493176]
# [0.35 0.34 0.34 0.78]
# 112 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446240f710>> expected = [0.3475882019998742, 0.3438271604938271, 0.3356778866453567, 0.7836257309941521]
# [0.69 0.69 0.71 0.73]
# 113 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446240fe50>> expected = [0.6936041758379976, 0.6904320987654321, 0.7083380602553575, 0.7270955165692006]
# [0.43 0.42 0.41 0.79]
# 114 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446240f8d0>> expected = [0.42846361864033705, 0.42438271604938266, 0.41114679650863195, 0.7894736842105261]
# [0.46 0.46 0.44 0.88]
# 115 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462416710>> expected = [0.456575058172442, 0.45555555555555555, 0.441215294762884, 0.8771929824561404]
# [0.55 0.55 0.52 0.8 ]
# 116 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446240f510>> expected = [0.545311615621659, 0.5453703703703703, 0.5202817798517856, 0.797270955165692]
# [0.58 0.58 0.55 0.72]
# 117 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462416c50>> expected = [0.5768819571096158, 0.5765432098765432, 0.549123180342832, 0.7231968810916181]
# [0.58 0.58 0.56 0.75]
# 118 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462416d10>> expected = [0.5826677567448588, 0.5820987654320987, 0.5558305987510437, 0.7543859649122808]
# [0.58 0.58 0.55 0.8 ]
# 119 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446241f710>> expected = [0.579145965662537, 0.5790123456790123, 0.5514914521747016, 0.797270955165692]
# [0.13 0.12 0.12 0.76]
# 120 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446241f7d0>> expected = [0.1330733916105905, 0.12253086419753087, 0.12255490269956226, 0.7602339181286548]
# [0.25 0.24 0.24 0.8 ]
# 121 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446241ff90>> expected = [0.2477831582919313, 0.24135802469135803, 0.2401065722324347, 0.7992202729044835]
# [0.69 0.68 0.7  0.89]
# 122 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446241fb50>> expected = [0.6878183762027545, 0.6839506172839506, 0.7016568217228212, 0.8927875243664718]
# [0.37 0.37 0.36 0.81]
# 123 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462428510>> expected = [0.37299540909376766, 0.3709876543209876, 0.360454022336512, 0.8089668615984404]
# [0.53 0.53 0.5  0.85]
# 124 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462428b10>> expected = [0.5285831079806301, 0.5268518518518518, 0.5029505103493648, 0.8479532163742691]
# [0.   0.   0.   0.78]
# 125 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446241ffd0>> expected = [0.002892899817621533, 0.0027777777777777775, 0.0017851222931142274, 0.7836257309941521]
# [0.01 0.01 0.   0.8 ]
# 126 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462428ad0>> expected = [0.006163134394063266, 0.005555555555555555, 0.004771833752641896, 0.8031189083820665]
# [0.54 0.54 0.51 0.77]
# 127 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462430410>> expected = [0.5357524683982139, 0.5351851851851851, 0.5097648538909141, 0.7699805068226122]
# [0.68 0.67 0.69 0.8 ]
# 128 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462430b90>> expected = [0.6753034400352179, 0.6703703703703703, 0.6907679113743086, 0.7953216374269005]
# [0.3  0.29 0.29 0.83]
# 129 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462430c50>> expected = [0.2968366769385573, 0.2898148148148148, 0.2878928048207854, 0.8265107212475633]
# [0.39 0.39 0.38 0.8 ]
# 130 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462428190>> expected = [0.3914219231494874, 0.3876543209876543, 0.3759138622633884, 0.797270955165692]
# [0.44 0.44 0.43 0.8 ]
# 131 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624394d0>> expected = [0.4449405697754858, 0.4435185185185185, 0.4280381865612526, 0.7953216374269005]
# [0.46 0.46 0.44 0.76]
# 132 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624395d0>> expected = [0.45839884284007293, 0.4574074074074074, 0.4427320014073928, 0.7582846003898633]
# [0.47 0.47 0.45 0.8 ]
# 133 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462439fd0>> expected = [0.4726746745487705, 0.4700617283950617, 0.45415122205841385, 0.8031189083820665]
# [0.03 0.02 0.02 0.78]
# 134 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624412d0>> expected = [0.025029872335073266, 0.020987654320987655, 0.019713158705570777, 0.7758284600389862]
# [0.28 0.27 0.27 0.78]
# 135 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462441890>> expected = [0.27652348908873653, 0.26975308641975304, 0.26812776584873177, 0.7797270955165692]
# [0.56 0.56 0.54 0.78]
# 136 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462428590>> expected = [0.5648072448273693, 0.5645061728395061, 0.5384460105273945, 0.7777777777777777]
# [0.27 0.27 0.27 0.71]
# 137 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462441fd0>> expected = [0.27281303062700457, 0.266358024691358, 0.2653935511390557, 0.7115009746588696]
# [0.   0.   0.   0.84]
# 138 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462441e50>> expected = [0.0038991258411420664, 0.003703703703703704, 0.002633906468048508, 0.8382066276803117]
# [0.55 0.55 0.52 0.82]
# 139 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462428710>> expected = [0.5468838437834098, 0.5472222222222222, 0.5215335231390554, 0.8226120857699804]
# [0.52 0.52 0.5  0.81]
# 140 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623c88d0>> expected = [0.5200301867807056, 0.5194444444444444, 0.4971702239491833, 0.807017543859649]
# [0.08 0.07 0.07 0.77]
# 141 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623c81d0>> expected = [0.07773096031696118, 0.06820987654320988, 0.06651683083111948, 0.7738791423001952]
# [0.86 0.86 0.87 0.83]
# 142 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d0190>> expected = [0.8635934846864977, 0.862037037037037, 0.8731459397650099, 0.8304093567251463]
# [0.34 0.33 0.33 0.85]
# 143 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d08d0>> expected = [0.3384063895352494, 0.3336419753086419, 0.3274746671343962, 0.8518518518518516]
# [0.76 0.76 0.77 0.71]
# 144 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d0d10>> expected = [0.756681969687441, 0.7561728395061728, 0.7698765911347039, 0.7134502923976607]
# [0.71 0.71 0.72 0.79]
# 145 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d0550>> expected = [0.7092006792025658, 0.707716049382716, 0.7236022703418428, 0.7875243664717351]
# [0.6  0.6  0.61 0.77]
# 146 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d0f10>> expected = [0.5996478208917678, 0.5966049382716049, 0.6145642388460146, 0.7680311890838207]
# [0.36 0.36 0.35 0.78]
# 147 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d6550>> expected = [0.3628073706056223, 0.3611111111111111, 0.3516712973720644, 0.7797270955165692]
# [0.71 0.7  0.72 0.75]
# 148 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d6cd0>> expected = [0.7058675554996541, 0.7046296296296296, 0.7202058869814039, 0.7543859649122808]
# [0.69 0.68 0.7  0.86]
# 149 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d6e90>> expected = [0.6870637066851141, 0.6833333333333333, 0.7010634112071159, 0.8635477582846005]
# [0.44 0.44 0.43 0.75]
# 150 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623df190>> expected = [0.4438085654990252, 0.4422839506172839, 0.4265807442507139, 0.7485380116959064]
# [0.25 0.24 0.24 0.83]
# 151 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623d0f50>> expected = [0.24784604741840133, 0.24135802469135803, 0.24015787711704206, 0.8343079922027292]
# [0.36 0.36 0.35 0.77]
# 152 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623df050>> expected = [0.3626815923526822, 0.3611111111111111, 0.3516082930558184, 0.7738791423001952]
# [0.37 0.37 0.36 0.67]
# 153 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623df750>> expected = [0.3669580529526445, 0.3657407407407407, 0.3554374594895364, 0.6666666666666665]
# [0.44 0.44 0.43 0.78]
# 154 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623dfb10>> expected = [0.4445632350166656, 0.4429012345679012, 0.4276282269693752, 0.7797270955165692]
# [0.21 0.2  0.2  0.79]
# 155 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623e65d0>> expected = [0.21294258222753285, 0.20462962962962963, 0.20316811018795988, 0.7875243664717351]
# [0.69 0.68 0.7  0.76]
# 156 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623e69d0>> expected = [0.685051254638073, 0.6811728395061728, 0.6995030714364532, 0.7582846003898633]
# [0.23 0.23 0.22 0.79]
# 157 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623e6ed0>> expected = [0.23224954405383308, 0.22623456790123456, 0.22390295532437676, 0.7894736842105261]
# [0.51 0.51 0.49 0.71]
# 158 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623ef250>> expected = [0.5071379158543488, 0.5067901234567901, 0.4860553803144967, 0.7115009746588696]
# [0.31 0.3  0.3  0.77]
# 159 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623efa10>> expected = [0.307464939311993, 0.3018518518518518, 0.2970730227696947, 0.7719298245614037]
# [0.64 0.64 0.66 0.77]
# 160 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623ef390>> expected = [0.6431670964090308, 0.6385802469135802, 0.6612843847015029, 0.7738791423001952]
# [0.05 0.04 0.04 0.76]
# 161 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623e6d10>> expected = [0.048487516508395695, 0.04135802469135802, 0.04130100748409404, 0.7582846003898633]
# [0.21 0.2  0.2  0.77]
# 162 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623f7250>> expected = [0.20715678259228976, 0.19907407407407407, 0.1963892485292149, 0.7738791423001952]
# [0.7  0.7  0.71 0.78]
# 163 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623f7690>> expected = [0.6979435255644298, 0.695679012345679, 0.7122249566713776, 0.7777777777777777]
# [0.65 0.64 0.66 0.74]
# 164 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623f7ad0>> expected = [0.6458084397207723, 0.6416666666666666, 0.6634211612223169, 0.7446393762183234]
# [0.46 0.46 0.45 0.79]
# 165 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623f7e90>> expected = [0.46424753160178606, 0.4629629629629629, 0.4475540851778135, 0.7875243664717351]
# [0.58 0.57 0.55 0.76]
# 166 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624005d0>> expected = [0.5753726180743349, 0.575, 0.5472713137512244, 0.7621832358674463]
# [0.47 0.47 0.45 0.96]
# 167 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462400950>> expected = [0.47336645493994084, 0.4703703703703703, 0.4544577088082633, 0.9551656920077973]
# [0.51 0.51 0.49 0.72]
# 168 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462400a50>> expected = [0.5111628199484309, 0.5104938271604937, 0.48980217124190517, 0.7192982456140351]
# [0.55 0.55 0.53 0.78]
# 169 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462400090>> expected = [0.5506571913716118, 0.5515432098765432, 0.5255004935338263, 0.7816764132553606]
# [0.13 0.11 0.12 0.81]
# 170 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462387290>> expected = [0.12584114206653668, 0.11450617283950618, 0.11586695137842185, 0.8089668615984404]
# [0.64 0.63 0.66 0.78]
# 171 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462387a50>> expected = [0.6378844097855481, 0.6342592592592592, 0.6568207638443937, 0.7816764132553606]
# [0.65 0.65 0.67 0.75]
# 172 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462387e90>> expected = [0.654801584805987, 0.6503086419753086, 0.6731795420670039, 0.7524366471734893]
# [0.62 0.62 0.64 0.81]
# 173 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462387b50>> expected = [0.6239230237092006, 0.619753086419753, 0.6442334220731993, 0.8109161793372319]
# [0.48 0.48 0.46 0.8 ]
# 174 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44624002d0>> expected = [0.47864914156342364, 0.4759259259259259, 0.4605531126865401, 0.7953216374269005]
# [0.06 0.05 0.05 0.81]
# 175 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462390a50>> expected = [0.06238601345827306, 0.05401234567901234, 0.053184273624026446, 0.8089668615984404]
# [0.13 0.12 0.12 0.84]
# 176 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462390e50>> expected = [0.12785359411357775, 0.1169753086419753, 0.11788213052790297, 0.8382066276803117]
# [0.34 0.34 0.33 0.81]
# 177 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462390190>> expected = [0.3423055153763914, 0.33734567901234563, 0.33090087445580707, 0.8128654970760234]
# [0.62 0.62 0.64 0.78]
# 178 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462397710>> expected = [0.6201496761209987, 0.616358024691358, 0.6401633624243175, 0.7758284600389862]
# [0.09 0.08 0.08 0.76]
# 179 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462397b50>> expected = [0.09370479844034965, 0.08148148148148149, 0.08150514530456121, 0.7641325536062378]
# [0.76 0.76 0.77 0.76]
# 180 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462390750>> expected = [0.7602037607697628, 0.7598765432098765, 0.773338280338919, 0.7621832358674463]
# [0.74 0.74 0.75 0.79]
# 181 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4462397c10>> expected = [0.7397019055405321, 0.7388888888888888, 0.7547346496984062, 0.7933723196881091]
# [0.54 0.54 0.52 0.77]
# 182 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623f7a90>> expected = [0.5445569461040186, 0.5444444444444444, 0.5198050759614432, 0.7719298245614037]
# [0.66 0.66 0.68 0.79]
# 183 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446239e710>> expected = [0.6613420539588705, 0.6561728395061728, 0.6785887071524144, 0.7914230019493176]
# [0.47 0.47 0.45 0.77]
# 184 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446239eed0>> expected = [0.4704106659958493, 0.4679012345679012, 0.45213997468511025, 0.7660818713450293]
# [0.02 0.02 0.02 0.73]
# 185 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446239ea10>> expected = [0.022577196402741966, 0.018209876543209876, 0.017371450337321903, 0.732943469785575]
# [0.93 0.93 0.94 0.87]
# 186 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623a5790>> expected = [0.934155084585875, 0.9293209876543209, 0.9374919506471997, 0.8674463937621835]
# [0.56 0.56 0.53 1.  ]
# 187 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623a5bd0>> expected = [0.5599018929627068, 0.5604938271604938, 0.5345388798484692, 0.996101364522417]
# [0.39 0.38 0.37 0.77]
# 188 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446239e5d0>> expected = [0.3872712408024652, 0.3833333333333333, 0.37176938655755976, 0.7738791423001952]
# [0.66 0.66 0.68 0.76]
# 189 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623a5d90>> expected = [0.662159612602981, 0.6570987654320988, 0.6795437451817747, 0.7641325536062378]
# [0.49 0.49 0.48 0.73]
# 190 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623ad750>> expected = [0.49449720143387205, 0.49320987654320986, 0.47546384650269147, 0.7309941520467835]
# [0.49 0.49 0.47 0.77]
# 191 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623adb90>> expected = [0.4904722973397899, 0.4885802469135802, 0.47171417866587717, 0.7699805068226122]
# [0.59 0.59 0.61 0.8 ]
# 192 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623adfd0>> expected = [0.5903402301742029, 0.5888888888888889, 0.6052956997779972, 0.801169590643275]
# [0.15 0.14 0.14 0.83]
# 193 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44623ad850>> expected = [0.14734922331928807, 0.13734567901234568, 0.13573220269515218, 0.8304093567251463]
# [0.29 0.28 0.28 0.77]
# ...
# [0.42 0.41 0.4  0.73]
# 4229 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607df6d0>> expected = [0.417017797622791, 0.4135802469135802, 0.3994794903689467, 0.7270955165692006]
# [0.68 0.68 0.7  0.75]
# 4230 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460832410>> expected = [0.6847368090057229, 0.6808641975308641, 0.6990405602992098, 0.7504873294346979]
# [0.12 0.11 0.11 0.81]
# 4231 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607df890>> expected = [0.12338846613420539, 0.11203703703703703, 0.11377572592337515, 0.8089668615984404]
# [0.2  0.19 0.19 0.75]
# 4232 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607df790>> expected = [0.1964656310923841, 0.18981481481481483, 0.18730674960349347, 0.7485380116959064]
# [0.68 0.68 0.7  0.79]
# 4233 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607e5190>> expected = [0.6828501352116219, 0.6790123456790124, 0.6975449509904195, 0.7894736842105261]
# [0.8  0.8  0.81 0.67]
# 4234 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607e5690>> expected = [0.8043519275517262, 0.8027777777777777, 0.8142011345188394, 0.6744639376218324]
# [0.07 0.06 0.06 0.79]
# 4235 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607e5a10>> expected = [0.07081315640525752, 0.06111111111111111, 0.0601701768637497, 0.7933723196881091]
# [0.55 0.55 0.52 0.79]
# 4236 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607e5dd0>> expected = [0.5454373938745991, 0.5453703703703703, 0.5203919654824745, 0.7855750487329436]
# [0.64 0.64 0.66 0.76]
# 4237 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607ee210>> expected = [0.6448651028237218, 0.6404320987654321, 0.6626111194275381, 0.7563352826510723]
# [0.66 0.66 0.68 0.78]
# 4238 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607eea50>> expected = [0.6615936104647506, 0.6564814814814814, 0.6788415874901546, 0.7797270955165692]
# [0.67 0.66 0.68 0.74]
# 4239 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607eee90>> expected = [0.6656185145588327, 0.6608024691358024, 0.6824913306732299, 0.7407407407407409]
# [0.5  0.5  0.48 0.76]
# 4240 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607eeb50>> expected = [0.49676120998679324, 0.49567901234567896, 0.47744450273918915, 0.7563352826510723]
# [0.36 0.35 0.35 0.79]
# 4241 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607e5d50>> expected = [0.3572102383497893, 0.35432098765432096, 0.3459814418245628, 0.7933723196881091]
# [0.3  0.29 0.29 0.75]
# 4242 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607f41d0>> expected = [0.2950757813973964, 0.2882716049382716, 0.2862973667552353, 0.7504873294346979]
# [0.1  0.08 0.09 0.79]
# 4243 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607f4d10>> expected = [0.09697503301679138, 0.08487654320987655, 0.08563514056629629, 0.7855750487329436]
# [0.21 0.2  0.2  0.76]
# 4244 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607f4cd0>> expected = [0.2051443305452487, 0.19722222222222222, 0.1956178532176125, 0.7602339181286548]
# [0.7  0.69 0.71 0.78]
# 4245 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607fb250>> expected = [0.6970001886673793, 0.6941358024691358, 0.7113228537752434, 0.7797270955165692]
# [0.53 0.53 0.51 0.78]
# 4246 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607fba10>> expected = [0.5331111250864725, 0.5320987654320988, 0.5071557847408315, 0.7836257309941521]
# [0.14 0.13 0.13 0.75]
# 4247 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607fbe50>> expected = [0.14256964970756555, 0.13209876543209878, 0.1311025841647222, 0.7524366471734893]
# [0.77 0.77 0.78 0.75]
# 4248 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607fb9d0>> expected = [0.7664297842902962, 0.7657407407407407, 0.7788783448027914, 0.7485380116959064]
# [0.35 0.35 0.34 0.76]
# 4249 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460802710>> expected = [0.3503553235645557, 0.3472222222222222, 0.3384123890459989, 0.7582846003898633]
# [0.4  0.4  0.38 0.77]
# 4250 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460802b50>> expected = [0.40047795736117225, 0.3972222222222222, 0.38391425966045745, 0.7680311890838207]
# [0.01 0.01 0.01 0.73]
# 4251 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460802c50>> expected = [0.008238475567574365, 0.0070987654320987656, 0.006670402173739376, 0.7309941520467835]
# [0.72 0.72 0.73 0.8 ]
# 4252 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460802c10>> expected = [0.719074272058361, 0.7188271604938271, 0.733597708522467, 0.801169590643275]
# [0.75 0.75 0.76 0.78]
# 4253 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446078a4d0>> expected = [0.7518395069492484, 0.7506172839506172, 0.763835273153461, 0.7758284600389862]
# [0.04 0.03 0.03 0.76]
# 4254 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446078ac90>> expected = [0.037859254134960066, 0.03209876543209876, 0.02950663784514518, 0.7602339181286548]
# [0.31 0.3  0.3  0.73]
# 4255 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446078a1d0>> expected = [0.30582982202377207, 0.2996913580246913, 0.2955955379902093, 0.7348927875243665]
# [0.45 0.45 0.44 0.71]
# 4256 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607ee6d0>> expected = [0.45160681718130935, 0.45061728395061723, 0.4366834911526212, 0.7076023391812867]
# [0.02 0.02 0.02 0.77]
# 4257 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446078a910>> expected = [0.024652537576253065, 0.020370370370370372, 0.019513309398092815, 0.7680311890838207]
# [0.75 0.75 0.76 0.75]
# 4258 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446078fa10>> expected = [0.7483177158669265, 0.7462962962962962, 0.7610935784792616, 0.7485380116959064]
# [0.41 0.4  0.39 0.76]
# 4259 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446078fe50>> expected = [0.4060750896170052, 0.40277777777777773, 0.38942507554526173, 0.7602339181286548]
# [0.44 0.44 0.43 0.77]
# 4260 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446078f9d0>> expected = [0.4439972328784353, 0.4422839506172839, 0.4266869022082176, 0.7738791423001952]
# [0.25 0.24 0.24 0.75]
# 4261 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446079a710>> expected = [0.24696559964782086, 0.2404320987654321, 0.23944967791561567, 0.7504873294346979]
# [0.39 0.39 0.37 0.77]
# 4262 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446079ab50>> expected = [0.3898496949877366, 0.38611111111111107, 0.3746623107701055, 0.7738791423001952]
# [0.4  0.4  0.39 0.81]
# 4263 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446079af90>> expected = [0.40374819193761396, 0.40061728395061724, 0.3876106087761002, 0.8128654970760234]
# [0.71 0.71 0.72 0.78]
# 4264 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446079ac50>> expected = [0.7088233444437456, 0.7074074074074074, 0.72341690147843, 0.7797270955165692]
# [0.62 0.61 0.64 0.77]
# 4265 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607a2850>> expected = [0.6157474372680963, 0.612037037037037, 0.635221503325198, 0.7719298245614037]
# [0.14 0.13 0.13 0.78]
# 4266 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607a2c90>> expected = [0.14313565184579585, 0.13240740740740742, 0.1313854802573644, 0.7836257309941521]
# [0.61 0.6  0.62 0.79]
# 4267 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607a21d0>> expected = [0.6061254009181812, 0.6027777777777777, 0.6239377851077279, 0.7855750487329436]
# [0.2  0.2  0.19 0.81]
# 4268 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607a7190>> expected = [0.20332054587761775, 0.195679012345679, 0.19283233362330066, 0.8050682261208579]
# [0.67 0.66 0.69 0.82]
# 4269 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607a7650>> expected = [0.6692660838940947, 0.6645061728395061, 0.685840053234358, 0.8206627680311889]
# [0.49 0.48 0.47 0.75]
# 4270 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446079a390>> expected = [0.48676183887805796, 0.4845679012345679, 0.46814949610453027, 0.7485380116959064]
# [0.67 0.66 0.68 0.73]
# 4271 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607a72d0>> expected = [0.6657442928117728, 0.6611111111111111, 0.6825692949184088, 0.7270955165692006]
# [0.33 0.33 0.32 0.76]
# 4272 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607a7a90>> expected = [0.3343814854411672, 0.32932098765432094, 0.32395496025694115, 0.7641325536062378]
# [0.59 0.59 0.61 0.81]
# 4273 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607b03d0>> expected = [0.5927929061065341, 0.5910493827160493, 0.6084661498522905, 0.8089668615984404]
# [0.03 0.02 0.02 0.78]
# 4274 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607b0b90>> expected = [0.02515565058801333, 0.020987654320987655, 0.019766189735832995, 0.7816764132553606]
# [0.65 0.65 0.67 0.72]
# 4275 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607b0fd0>> expected = [0.6517829067354254, 0.6481481481481481, 0.669263492968895, 0.7173489278752436]
# [0.59 0.58 0.56 0.78]
# 4276 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607b70d0>> expected = [0.58505754355072, 0.5839506172839506, 0.5580102412221493, 0.7836257309941521]
# [0.67 0.66 0.69 0.79]
# 4277 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607b7890>> expected = [0.6689516382617445, 0.6641975308641975, 0.6856281209073245, 0.7914230019493176]
# [0.63 0.62 0.65 0.7 ]
# 4278 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607b7cd0>> expected = [0.6270674800327023, 0.6228395061728395, 0.6467088108323935, 0.6978557504873293]
# [0.21 0.21 0.2  0.8 ]
# 4279 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607b7c90>> expected = [0.21394880825105336, 0.20555555555555555, 0.20378041240880407, 0.801169590643275]
# [0.41 0.4  0.39 0.8 ]
# 4280 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607bc190>> expected = [0.40802465253757625, 0.4049382716049382, 0.3908683251026446, 0.7953216374269005]
# [0.24 0.24 0.24 0.79]
# 4281 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607bc690>> expected = [0.24413558895666937, 0.23796296296296296, 0.2373465612349719, 0.7933723196881091]
# [0.53 0.53 0.5  0.78]
# 4282 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607bce10>> expected = [0.5279542167159298, 0.5259259259259259, 0.5022865196559678, 0.7816764132553606]
# [0.51 0.51 0.49 0.71]
# 4283 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607bce90>> expected = [0.513175271995472, 0.5123456790123456, 0.4908772722909305, 0.7115009746588696]
# [0.37 0.37 0.36 0.85]
# 4284 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f44607b0810>> expected = [0.36764983334381485, 0.36604938271604937, 0.35582277355743486, 0.8460038986354776]
# [0.1  0.09 0.09 0.79]
# 4285 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460745450>> expected = [0.09886170681089239, 0.08734567901234568, 0.08803505840177195, 0.7914230019493176]
# [0.76 0.76 0.77 0.76]
# 4286 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460745bd0>> expected = [0.7607068737815231, 0.7604938271604937, 0.7739139499132079, 0.7602339181286548]
# [0.51 0.51 0.49 0.8 ]
# 4287 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460745d90>> expected = [0.5088988113955097, 0.508641975308642, 0.48779936280291736, 0.8031189083820665]
# [0.15 0.14 0.14 0.77]
# 4288 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446074c190>> expected = [0.1523174643104207, 0.14135802469135803, 0.1398875147597778, 0.7660818713450293]
# [0.44 0.44 0.43 0.76]
# 4289 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446074c8d0>> expected = [0.44412301113137537, 0.44259259259259254, 0.42706099632937367, 0.7641325536062378]
# [0.33 0.33 0.32 0.78]
# 4290 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446074cd10>> expected = [0.33148858562354566, 0.32623456790123456, 0.32000458003977883, 0.7816764132553606]
# [0.47 0.47 0.45 0.73]
# 4291 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f446074ccd0>> expected = [0.4700333312370291, 0.46759259259259256, 0.4519490437968443, 0.7348927875243665]
# [0.37 0.37 0.36 0.78]
# 4292 : predicted = <bound method AutoRegResults.predict of <statsmodels.tsa.ar_model.AutoRegResultsWrapper object at 0x7f4460752250>> expected = [0.37010250927614613, 0.36820987654320986, 0.35742492441161744, 0.7836257309941521]

# %% [markdown]
# **Deep learning for time series forecasting**

# %%
# read the data
X = pd.read_csv ('/kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_temp.csv')
y = pd.read_csv ('/kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_temp_FULL_with_test.csv')

# sampling the data in X
X = X ['time'].sample(5000)

# sampling the data in y
y = y ['time'].sample (5000)

# %%
# setting T - the number of lag variables 
T = 1

# setting the horizon, as we interesting in predicting next day
HORIZON = 1

# %%
# convert datasets to time series
X = pd.to_datetime(X) 
y = pd.to_datetime(y)

# %%
# create train set containing only the model features
X_train, y_train, X_test, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

print ('Training data shape X: ', X_train.shape)
print ('Test data shape X: ', X_test.shape)
print ('Training data shape y: ', y_train.shape)
print ('Test data shape y: ', y_test.shape)
# Out:
# Training data shape X:  (2500,)
# Test data shape X:  (2500,)
# Training data shape y:  (2500,)
# Test data shape y:  (2500,)

# %%
# create a validation set
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, train_size=0.5)

print ('Validation data shape X: ', X_valid.shape)
print ('Validation data shape y: ', y_valid.shape)
# Out:
# Validation data shape X:  (1250,)
# Validation data shape y:  (1250,)

# %%
# converting data
X_train = np.asarray(X_train).astype(np.float32)
y_train = np.asarray(y_train).astype(np.float32)
X_test = np.asarray(X_test).astype(np.float32)
y_test = np.asarray(y_test).astype(np.float32)
X_valid = np.asarray (X_valid).astype (np.float32)
y_valid = np.asarray (y_valid).astype (np.float32)

# %%
# rescale the data to 0-1 scale
min_max_scaler = MinMaxScaler(feature_range=(0, 1))
X_train = min_max_scaler.fit_transform(X_train.reshape(-1, 1))
y_train = min_max_scaler.fit_transform(y_train.reshape(-1, 1)) 
X_test = min_max_scaler.fit_transform(X_test.reshape(-1, 1))
y_test = min_max_scaler.fit_transform(y_test.reshape(-1, 1))
X_valid = min_max_scaler.fit_transform(X_valid.reshape(-1, 1))
y_valid = min_max_scaler.fit_transform(y_valid.reshape(-1, 1))

# %%
# reshape the data
X_train = np.reshape(X_train, (X_train.shape[0], T, X_train.shape[1]))
y_train = np.reshape(y_train, (y_train.shape[0], T, y_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], T, X_test.shape[1]))
y_test = np.reshape(y_test, (y_test.shape[0], T, y_test.shape[1]))
X_valid = np.reshape(X_valid, (X_valid.shape[0], T, X_valid.shape[1]))
y_valid = np.reshape(y_valid, (y_valid.shape[0], T, y_valid.shape[1]))

# %% [markdown]
# **Univariate models**

# %%
# number of units in the RNN layer
LATENT_DIM = 5  

# number of samples per mini-batch
BATCH_SIZE = 32

# maximum number of times the training algorithm will cycle through all samples
EPOCHS = 15

# define model and create a Sequential model
model = Sequential ()
model.add (GRU (LATENT_DIM, input_shape = (T, 1)))
model.add (Dense (HORIZON))

model.compile (optimizer = 'RMSprop', loss = 'mse')
model.summary ()
# Out:
# 2023-01-07 18:46:04.098961: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    (None, 5)                 120
# _________________________________________________________________
# dense (Dense)                (None, 1)                 6
# =================================================================
# Total params: 126
# Trainable params: 126
# Non-trainable params: 0
# _________________________________________________________________

# %%
# specify early stop criteria
GRU_earlystop = EarlyStopping (monitor = 'val_loss', min_delta = 0, patience = 5)

# fit our model
history = model.fit (X_train, y_train, batch_size = BATCH_SIZE, epochs = EPOCHS, validation_data = (X_valid, y_valid),
                           callbacks = [GRU_earlystop], verbose = 1)
# Out:
# 2023-01-07 18:46:04.734049: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/15
# 40/40 [==============================] - 3s 18ms/step - loss: 0.3955 - val_loss: 0.3067
# Epoch 2/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.2485 - val_loss: 0.1928
# Epoch 3/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1554 - val_loss: 0.1204
# Epoch 4/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.1022 - val_loss: 0.0889
# Epoch 5/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0876 - val_loss: 0.0867
# Epoch 6/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0870 - val_loss: 0.0861
# Epoch 7/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0869 - val_loss: 0.0861
# Epoch 8/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0869 - val_loss: 0.0862
# Epoch 9/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0870 - val_loss: 0.0861
# Epoch 10/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0868 - val_loss: 0.0861
# Epoch 11/15
# 40/40 [==============================] - 0s 5ms/step - loss: 0.0869 - val_loss: 0.0864

# %%
# plot the epochs and train_loss and val_loss
plot_df = pd.DataFrame.from_dict({'train_loss':history.history['loss'], 'val_loss':history.history['val_loss']})
plot_df.plot(logy=True, figsize=(10,10), fontsize=12)
plt.xlabel('epoch', fontsize=12)
plt.ylabel('loss', fontsize=12)
plt.show()

# %% [markdown]
# *The number of losses decreases with increasing epochs*

# %%
# make the predictiondson the X_test and compare those predictions on the y_test
ts_predictions = model.predict (X_test)
ev_ts_data = pd.DataFrame (ts_predictions)
ev_ts_data ['prediction' ]= pd.DataFrame (ts_predictions)
ev_ts_data ['actual'] = np.transpose (y_test).ravel ()

# evaluate our model and compute MAPE (mean absolute percentage error)  
def mape (ts_predictions, actuals):
    return ((ts_predictions - actuals).abs () / actuals).mean ()

mape (ev_ts_data ['prediction'], ev_ts_data ['actual'])
# Out:
# inf

# %%
# plot the count of predictions
ev_ts_data ['actual' < '0.3'].plot (x = 'prediction', style = ['r', 'b'], figsize = (15, 8))
plt.xlabel ('prediction', fontsize = 12)
plt.ylabel ('count', fontsize = 12)
plt.show ()

# %% [markdown]
# **Let's try Time series forecasting with Machine Learning for supplied electricity dataset**

# %%
# import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xgboost as xgb
from sklearn.metrics import mean_squared_error
color_pal = sns.color_palette()
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv('/kaggle/input/industrial-data-from-the-ladlefurnace-unit/data_arc.csv')
df = df.set_index('Heating start')
df = df.set_index('Heating end')
df.index = pd.to_datetime(df.index)

# %%
df['Active power'].plot(style='.',
        figsize=(15, 5),
        color=color_pal[0],
        title='Supply electricity')
plt.show()

# %% [markdown]
# **Split the data in train and test datasets**

# %%
train = df.loc[df.index < '01-09-2019']
test = df.loc[df.index >= '05-01-2019']

fig, ax = plt.subplots(figsize=(15, 5))
train['Active power'].plot(ax=ax, label='Training Set', title='Data Train/Test Split')
test['Active power'].plot(ax=ax, label='Test Set')
ax.axvline('05-01-2019', color='black', ls='--')
ax.legend(['Training Set', 'Test Set'])
plt.show()

# %% [markdown]
# **We will produce feature creation**

# %%
def create_features(df):
    """
    Create time series features based on time series index.
    """
    df = df.copy()
    df['hour'] = df.index.hour
    df['dayofweek'] = df.index.dayofweek
    df['quarter'] = df.index.quarter
    df['month'] = df.index.month
    df['year'] = df.index.year
    df['dayofyear'] = df.index.dayofyear
    df['dayofmonth'] = df.index.day
    df['weekofyear'] = df.index.isocalendar().week
    return df

df = create_features(df)

# %% [markdown]
# **We visualize our Feature and Target Relationship**

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='hour', y='month')
ax.set_title('Supply by Hour')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 8))
sns.boxplot(data=df, x='month', y='dayofmonth', palette='Blues')
ax.set_title('Supply by Month')
plt.show()

# %% [markdown]
# **We create our model**

# %%
train = create_features(df)
test = create_features(df)

FEATURES = ['dayofyear', 'hour', 'dayofweek', 'quarter', 'month', 'year']
TARGET = 'Active power'

X_train = train[FEATURES]
y_train = train[TARGET]

X_test = test[FEATURES]
y_test = test[TARGET]

# %%
reg = xgb.XGBRegressor(base_score=0.5, booster='gbtree',    
                       n_estimators=1000,
                       early_stopping_rounds=50,
                       objective='reg:linear',
                       max_depth=3,
                       learning_rate=0.01)
reg.fit(X_train, y_train,
        eval_set=[(X_train, y_train), (X_test, y_test)],
        verbose=100)
# Out:
# [18:46:17] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation_0-rmse:0.44163	validation_1-rmse:0.44163
# [100]	validation_0-rmse:0.41169	validation_1-rmse:0.41169
# [200]	validation_0-rmse:0.40691	validation_1-rmse:0.40691
# [300]	validation_0-rmse:0.40585	validation_1-rmse:0.40585
# [400]	validation_0-rmse:0.40531	validation_1-rmse:0.40531
# [500]	validation_0-rmse:0.40487	validation_1-rmse:0.40487
# [600]	validation_0-rmse:0.40451	validation_1-rmse:0.40451
# [700]	validation_0-rmse:0.40415	validation_1-rmse:0.40415
# [800]	validation_0-rmse:0.40386	validation_1-rmse:0.40386
# [900]	validation_0-rmse:0.40355	validation_1-rmse:0.40355
# [999]	validation_0-rmse:0.40311	validation_1-rmse:0.40311
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=50, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.01, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=3, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=0, num_parallel_tree=1, objective='reg:linear',
#              predictor='auto', random_state=0, reg_alpha=0, ...)

# %% [markdown]
# **Create the feature importance visualization**

# %%
fi = pd.DataFrame(data=reg.feature_importances_,
             index=reg.feature_names_in_,
             columns=['importance'])
fi.sort_values('importance').plot(kind='barh', title='Feature Importance')
plt.show()

# %% [markdown]
# **We will produce forecast on test dataset**

# %%
test['prediction'] = reg.predict(X_test)
df = df.merge(test[['prediction']], how='left', left_index=True, right_index=True)
ax = df['Active power'].plot(figsize=(15, 5))
df['prediction'].plot(ax=ax, style='.')
plt.legend(['Truth Data', 'Predictions'])
ax.set_title('Raw Data and Prediction')
plt.show()

# %%
ax = df.loc[(df.index > '05-01-2019') & (df.index < '09-01-2019')]['Active power'] \
    .plot(figsize=(15, 5), title='Week Of Data')
df.loc[(df.index > '05-01-2019') & (df.index < '09-01-2019')]['prediction'] \
    .plot(style='.')
plt.legend(['Truth Data','Prediction'])
plt.show()

# %% [markdown]
# **Calcalute the Root-mean-square deviation (RMSE)**

# %%
score = np.sqrt(mean_squared_error(test['Active power'], test['prediction']))
print(f'RMSE Score on Test set: {score:0.2f}')
# Out:
# RMSE Score on Test set: 0.40
